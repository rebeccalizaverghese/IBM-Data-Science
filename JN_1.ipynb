# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Rebecca Liza Verghese**
#
# Data Scienist

# %% [markdown]
# *I derived an interest in data science and its related field due to a Business Analytics course I had taken as part of my college curriculum. I enjoy writing different codes on Python for solving different problems.*

# %% [markdown]
# ### Arithmetic Expression in Python

# %%
#Addition:
Sum = 30+3
# Subtraction
Diff = 33-3
#Multiplcation
Mult = 3*11
#Division
Div = 30/10

print("30+3=", Sum)
print("33-3=", Diff)
print("3*11=", Mult)
print("30/10=", Div)
# Out:
# 30+3= 33
# 33-3= 30
# 3*11= 33
# 30/10= 3.0

# %% [markdown]
# ## More about Data Science

# %% [markdown]
# #### Data Science Languages
# 1. Python
# 2. R
# 3. Java
# 4. Scala

# %% [markdown]
# #### Data Science Libraries
# * Pandas
# * Numpy
# * Matplotlib

# %% [markdown]
# |Data Science Tool|
# |-----------------|
# |RStudio|
# |Jupyter Notebooks|
# |Watson Studio|
